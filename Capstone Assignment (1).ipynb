# %% [markdown]
# ## CAPSTONE PROJECT NOTEBOOK

# %%
import pandas as pd
import numpy as np
import os

# %%
print ('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %%
import types
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_2f00fa013de6423abb1c26724fbae734 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='iz7d_6-ybMUJMjv5V5GOJOBCYYcbiHNAPFTB6LiN4_LJ',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_2f00fa013de6423abb1c26724fbae734.get_object(Bucket='courseracapstone-donotdelete-pr-riyuqbjehh42bk',Key='Data-Collisions.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df = pd.read_csv(body)
df.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# ...

# %%
print(df.shape)
# Out:
# (194673, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 38 columns):
# SEVERITYCODE      194673 non-null int64
# X                 189339 non-null float64
# Y                 189339 non-null float64
# OBJECTID          194673 non-null int64
# INCKEY            194673 non-null int64
# COLDETKEY         194673 non-null int64
# REPORTNO          194673 non-null object
# STATUS            194673 non-null object
# ADDRTYPE          192747 non-null object
# INTKEY            65070 non-null float64
# LOCATION          191996 non-null object
# EXCEPTRSNCODE     84811 non-null object
# EXCEPTRSNDESC     5638 non-null object
# SEVERITYCODE.1    194673 non-null int64
# SEVERITYDESC      194673 non-null object
# COLLISIONTYPE     189769 non-null object
# PERSONCOUNT       194673 non-null int64
# PEDCOUNT          194673 non-null int64
# PEDCYLCOUNT       194673 non-null int64
# VEHCOUNT          194673 non-null int64
# ...

# %%
df.describe()
# Out:
#         SEVERITYCODE              X              Y       OBJECTID  \
# count  194673.000000  189339.000000  189339.000000  194673.000000
# mean        1.298901    -122.330518      47.619543  108479.364930
# std         0.457778       0.029976       0.056157   62649.722558
# min         1.000000    -122.419091      47.495573       1.000000
# 25%         1.000000    -122.348673      47.575956   54267.000000
# 50%         1.000000    -122.330224      47.615369  106912.000000
# 75%         2.000000    -122.311937      47.663664  162272.000000
# max         2.000000    -122.238949      47.734142  219547.000000
#
#               INCKEY      COLDETKEY         INTKEY  SEVERITYCODE.1  \
# count  194673.000000  194673.000000   65070.000000   194673.000000
# mean   141091.456350  141298.811381   37558.450576        1.298901
# std     86634.402737   86986.542110   51745.990273        0.457778
# min      1001.000000    1001.000000   23807.000000        1.000000
# ...

# %%
df.drop(['SEVERITYCODE.1'], axis = 1, inplace = True)

# %%
print(df.shape)
# Out:
# (194673, 37)

# %%
import seaborn as sns
ax = sns.regplot(x='PERSONCOUNT', y='SEVERITYCODE', data=df)

# %%
import seaborn as sns
ax = sns.regplot(x='VEHCOUNT', y='SEVERITYCODE', data=df)

# %%
ax = sns.regplot(x='SEVERITYCODE', y='PERSONCOUNT', data=df)

# %%
ax = sns.regplot(x='SEVERITYCODE', y='VEHCOUNT', data=df)

# %%
df['WEATHER'].value_counts()
# Out:
# Clear                       111135
# Raining                      33145
# Overcast                     27714
# Unknown                      15091
# Snowing                        907
# Other                          832
# Fog/Smog/Smoke                 569
# Sleet/Hail/Freezing Rain       113
# Blowing Sand/Dirt               56
# Severe Crosswind                25
# Partly Cloudy                    5
# Name: WEATHER, dtype: int64

# %%
df['ROADCOND'].value_counts()
# Out:
# Dry               124510
# Wet                47474
# Unknown            15078
# Ice                 1209
# Snow/Slush          1004
# Other                132
# Standing Water       115
# Sand/Mud/Dirt         75
# Oil                   64
# Name: ROADCOND, dtype: int64

# %%
df['LIGHTCOND'].value_counts()
# Out:
# Daylight                    116137
# Dark - Street Lights On      48507
# Unknown                      13473
# Dusk                          5902
# Dawn                          2502
# Dark - No Street Lights       1537
# Dark - Street Lights Off      1199
# Other                          235
# Dark - Unknown Lighting         11
# Name: LIGHTCOND, dtype: int64

# %%
df['SPEEDING'].value_counts()
# Out:
# Y    9333
# Name: SPEEDING, dtype: int64

# %%
df['SEVERITYCODE'].value_counts()
# Out:
# 1    136485
# 2     58188
# Name: SEVERITYCODE, dtype: int64

# %%
df['SEVERITYDESC'].value_counts()
# Out:
# Property Damage Only Collision    136485
# Injury Collision                   58188
# Name: SEVERITYDESC, dtype: int64

# %%
df_any=df[['SEVERITYCODE','ADDRTYPE','WEATHER','ROADCOND','LIGHTCOND','SPEEDING','HITPARKEDCAR','COLLISIONTYPE','PERSONCOUNT','PEDCOUNT','PEDCYLCOUNT','VEHCOUNT','INCDTTM']]

# %%
df_any.head()
# Out:
#    SEVERITYCODE      ADDRTYPE   WEATHER ROADCOND                LIGHTCOND  \
# 0             2  Intersection  Overcast      Wet                 Daylight
# 1             1         Block   Raining      Wet  Dark - Street Lights On
# 2             1         Block  Overcast      Dry                 Daylight
# 3             1         Block     Clear      Dry                 Daylight
# 4             2  Intersection   Raining      Wet                 Daylight
#
#   SPEEDING HITPARKEDCAR COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  \
# 0      NaN            N        Angles            2         0            0
# 1      NaN            N     Sideswipe            2         0            0
# 2      NaN            N    Parked Car            4         0            0
# 3      NaN            N         Other            3         0            0
# 4      NaN            N        Angles            2         0            0
#
#    VEHCOUNT                 INCDTTM
# 0         2    3/27/2013 2:54:00 PM
# ...

# %%
df_any["ADDRTYPE"].replace({"Intersection":"1","Block":"2","Alley":"3"}, inplace=True)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df['ADDRTYPE'].value_counts()
# Out:
# Block           126926
# Intersection     65070
# Alley              751
# Name: ADDRTYPE, dtype: int64

# %%
df_any['ADDRTYPE'].value_counts()
# Out:
# 2    126926
# 1     65070
# 3       751
# Name: ADDRTYPE, dtype: int64

# %%
df_any["ROADCOND"].replace({"Dry":"1","Wet":"2","Ice":"3","Unknown":"9","Snow/Slush":"4","Other":"5","Standing Water":"6","Sand/Mud/Dirt":"7","Oil":"8"}, inplace=True)

# %%
df_any['ADDRTYPE'] = df_any['ADDRTYPE'].fillna(0)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_any = df_any.fillna(0)

# %%
df_any['ADDRTYPE'] = df_any['ADDRTYPE'].astype(int)

# %%
df_any['ADDRTYPE'].value_counts()
# Out:
# 2    126926
# 1     65070
# 0      1926
# 3       751
# Name: ADDRTYPE, dtype: int64

# %%
df_any.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 13 columns):
# SEVERITYCODE     194673 non-null int64
# ADDRTYPE         194673 non-null int64
# WEATHER          194673 non-null object
# ROADCOND         194673 non-null object
# LIGHTCOND        194673 non-null object
# SPEEDING         194673 non-null object
# HITPARKEDCAR     194673 non-null object
# COLLISIONTYPE    194673 non-null object
# PERSONCOUNT      194673 non-null int64
# PEDCOUNT         194673 non-null int64
# PEDCYLCOUNT      194673 non-null int64
# VEHCOUNT         194673 non-null int64
# INCDTTM          194673 non-null object
# dtypes: int64(6), object(7)
# memory usage: 19.3+ MB

# %%
ax = sns.regplot(x='ADDRTYPE', y='SEVERITYCODE', data=df_any)

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_any['ROADCOND'] = df_any['ROADCOND'].fillna(0)
df_any['ROADCOND'] = df_any['ROADCOND'].astype(int)

# %%
df_any["WEATHER"].replace({"Clear":"1","Raining":"2","Overcast":"3","Unknown":"9","Snowing":"4","Other":"5","Fog/Smog/Smoke":"6","Sleet/Hail/Freezing Rain":"7","Blowing Sand/Dirt":"8","Severe Crosswind":"10","Partly Cloudy":"11"}, inplace=True)
df_any['WEATHER'] = df_any['WEATHER'].fillna(0)
df_any['WEATHER'] = df_any['WEATHER'].astype(int)

# %%
df['LIGHTCOND'].value_counts()
# Out:
# Daylight                    116137
# Dark - Street Lights On      48507
# Unknown                      13473
# Dusk                          5902
# Dawn                          2502
# Dark - No Street Lights       1537
# Dark - Street Lights Off      1199
# Other                          235
# Dark - Unknown Lighting         11
# Name: LIGHTCOND, dtype: int64

# %%
df_any["LIGHTCOND"].replace({"Daylight":"1","Dark - Street Lights On":"2","Dusk":"3","Unknown":"9","Dawn":"4","Other":"5","Dark - No Street Lights":"6","Dark - Street Lights Off":"7","Dark - Unknown Lighting":"8"}, inplace=True)
df_any['LIGHTCOND'] = df_any['LIGHTCOND'].fillna(0)
df_any['LIGHTCOND'] = df_any['LIGHTCOND'].astype(int)

# %%
df_any.head()
# Out:
#    SEVERITYCODE  ADDRTYPE  WEATHER  ROADCOND  LIGHTCOND SPEEDING HITPARKEDCAR  \
# 0             2         1        3         2          1        0            N
# 1             1         2        2         2          2        0            N
# 2             1         2        3         1          1        0            N
# 3             1         2        1         1          1        0            N
# 4             2         1        2         2          1        0            N
#
#   COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0        Angles            2         0            0         2
# 1     Sideswipe            2         0            0         2
# 2    Parked Car            4         0            0         3
# 3         Other            3         0            0         3
# 4        Angles            2         0            0         2
#
#                   INCDTTM
# 0    3/27/2013 2:54:00 PM
# 1   12/20/2006 6:55:00 PM
# 2  11/18/2004 10:20:00 AM
# ...

# %%
df_any['DAYTIME'] = df_any.INCDTTM.str[-2:]

# %%
df_any.head()
# Out:
#    SEVERITYCODE  ADDRTYPE  WEATHER  ROADCOND  LIGHTCOND SPEEDING HITPARKEDCAR  \
# 0             2         1        3         2          1        0            N
# 1             1         2        2         2          2        0            N
# 2             1         2        3         1          1        0            N
# 3             1         2        1         1          1        0            N
# 4             2         1        2         2          1        0            N
#
#   COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0        Angles            2         0            0         2
# 1     Sideswipe            2         0            0         2
# 2    Parked Car            4         0            0         3
# 3         Other            3         0            0         3
# 4        Angles            2         0            0         2
#
#                   INCDTTM DAYTIME
# 0    3/27/2013 2:54:00 PM      PM
# 1   12/20/2006 6:55:00 PM      PM
# ...

# %%
df_any['DAYTIME'].value_counts()
# Out:
# PM    106686
# AM     57461
# 06      4609
# 05      4463
# 07      4337
# 08      4073
# 04      3619
# 09      3399
# 20       989
# 16       774
# 12       686
# 19       682
# 13       665
# 11       626
# 18       544
# 17       427
# 14       263
# 15       242
# 10       128
# Name: DAYTIME, dtype: int64

# %%
df_any["DAYTIME"].replace({"AM":"1","PM":"2","06":"0","05":"0","07":"0","08":"0","04":"0","09":"0","20":"0","16":"0","12":"0","19":"0","13":"0","11":"0","18":"0","17":"0","14":"0","15":"0","10":"0"}, inplace=True)
df_any['DAYTIME'] = df_any['DAYTIME'].fillna(0)
df_any['DAYTIME'] = df_any['DAYTIME'].astype(int)
df_any['DAYTIME'].value_counts()
# Out:
# 2    106686
# 1     57461
# 0     30526
# Name: DAYTIME, dtype: int64

# %%
df_any.head()
# Out:
#    SEVERITYCODE  ADDRTYPE  WEATHER  ROADCOND  LIGHTCOND SPEEDING HITPARKEDCAR  \
# 0             2         1        3         2          1        0            N
# 1             1         2        2         2          2        0            N
# 2             1         2        3         1          1        0            N
# 3             1         2        1         1          1        0            N
# 4             2         1        2         2          1        0            N
#
#   COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0        Angles            2         0            0         2
# 1     Sideswipe            2         0            0         2
# 2    Parked Car            4         0            0         3
# 3         Other            3         0            0         3
# 4        Angles            2         0            0         2
#
#                   INCDTTM  DAYTIME
# 0    3/27/2013 2:54:00 PM        2
# 1   12/20/2006 6:55:00 PM        2
# ...

# %%
df_any['COLLISIONTYPE'].value_counts()
# Out:
# Parked Car    47987
# Angles        34674
# Rear Ended    34090
# Other         23703
# Sideswipe     18609
# Left Turn     13703
# Pedestrian     6608
# Cycles         5415
# 0              4904
# Right Turn     2956
# Head On        2024
# Name: COLLISIONTYPE, dtype: int64

# %%
df_any["COLLISIONTYPE"].replace({"Parked Car":"1","Angles":"2","Rear Ended":"3","Other":"4","Sideswipe":"5","Left Turn":"6","Pedestrian":"7","Cycles":"8","Right Turn":"9","Head On":"10"}, inplace=True)
df_any['COLLISIONTYPE'] = df_any['COLLISIONTYPE'].fillna(0)
df_any['COLLISIONTYPE'] = df_any['COLLISIONTYPE'].astype(int)

# %%
df_any['SPEEDING'].value_counts()
# Out:
# 0    185340
# Y      9333
# Name: SPEEDING, dtype: int64

# %%
df_any["SPEEDING"].replace({"Y":"1"}, inplace=True)
df_any['SPEEDING'] = df_any['SPEEDING'].fillna(0)
df_any['SPEEDING'] = df_any['SPEEDING'].astype(int)

# %%
df_any['HITPARKEDCAR'].value_counts()
# Out:
# N    187457
# Y      7216
# Name: HITPARKEDCAR, dtype: int64

# %%
df_any["HITPARKEDCAR"].replace({"Y":"1","N":"2"}, inplace=True)
df_any['HITPARKEDCAR'] = df_any['HITPARKEDCAR'].fillna(0)
df_any['HITPARKEDCAR'] = df_any['HITPARKEDCAR'].astype(int)

# %%
df_any.head()
# Out:
#    SEVERITYCODE  ADDRTYPE  WEATHER  ROADCOND  LIGHTCOND  SPEEDING  \
# 0             2         1        3         2          1         0
# 1             1         2        2         2          2         0
# 2             1         2        3         1          1         0
# 3             1         2        1         1          1         0
# 4             2         1        2         2          1         0
#
#    HITPARKEDCAR  COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0             2              2            2         0            0         2
# 1             2              5            2         0            0         2
# 2             2              1            4         0            0         3
# 3             2              4            3         0            0         3
# 4             2              2            2         0            0         2
#
#                   INCDTTM  DAYTIME
# 0    3/27/2013 2:54:00 PM        2
# ...

# %%
df_any.tail()
# Out:
#         SEVERITYCODE  ADDRTYPE  WEATHER  ROADCOND  LIGHTCOND  SPEEDING  \
# 194668             2         2        1         1          1         0
# 194669             1         2        2         2          1         0
# 194670             2         1        1         1          1         0
# 194671             2         1        1         1          3         0
# 194672             1         2        1         2          1         0
#
#         HITPARKEDCAR  COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  \
# 194668             2             10            3         0            0
# 194669             2              3            2         0            0
# 194670             2              6            3         0            0
# 194671             2              8            2         0            1
# 194672             2              3            2         0            0
#
#         VEHCOUNT                INCDTTM  DAYTIME
# 194668         2  11/12/2018 8:12:00 AM        1
# ...

# %%
ADD = df.groupby(['ADDRTYPE', 'SEVERITYCODE']).size()
ADD.plot.barh()

# %%
WEATHER = df.groupby(['WEATHER', 'SEVERITYCODE']).size()
WEATHER.plot.barh()

# %%
ROADCOND = df.groupby(['ROADCOND', 'SEVERITYCODE']).size()
ROADCOND.plot.barh()

# %%
LIGHTCOND = df.groupby(['LIGHTCOND', 'SEVERITYCODE']).size()
LIGHTCOND.plot.barh()

# %%
VEHICLE = df.groupby(['VEHCOUNT', 'SEVERITYCODE']).size()
VEHICLE.plot.bar()

# %%
DAYTIME = df_any.groupby(['DAYTIME', 'SEVERITYCODE']).size()
DAYTIME.plot.barh()

# %%
SEVERITY = df_any.groupby(['SEVERITYCODE']).size()
SEVERITY.plot.bar()

# %%
df_any['SEVERITYCODE']=df['SEVERITYCODE'].copy()
df_any.head()
# Out:
#    SEVERITYCODE  ADDRTYPE  WEATHER  ROADCOND  LIGHTCOND  SPEEDING  \
# 0             2         1        3         2          1         0
# 1             1         2        2         2          2         0
# 2             1         2        3         1          1         0
# 3             1         2        1         1          1         0
# 4             2         1        2         2          1         0
#
#    HITPARKEDCAR  COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0             2              2            2         0            0         2
# 1             2              5            2         0            0         2
# 2             2              1            4         0            0         3
# 3             2              4            3         0            0         3
# 4             2              2            2         0            0         2
#
#                   INCDTTM  DAYTIME SEVCODE1 SEVCODE2  SEVCODE
# ...

# %%
df_any['SEVCODE1']=df['SEVERITYCODE'].copy()
df_any['SEVCODE2']=df['SEVERITYCODE'].copy()
df_any.head()
# Out:
#    SEVERITYCODE  ADDRTYPE  WEATHER  ROADCOND  LIGHTCOND  SPEEDING  \
# 0             2         1        3         2          1         0
# 1             1         2        2         2          2         0
# 2             1         2        3         1          1         0
# 3             1         2        1         1          1         0
# 4             2         1        2         2          1         0
#
#    HITPARKEDCAR  COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0             2              2            2         0            0         2
# 1             2              5            2         0            0         2
# 2             2              1            4         0            0         3
# 3             2              4            3         0            0         3
# 4             2              2            2         0            0         2
#
#                   INCDTTM  DAYTIME  SEVCODE1  SEVCODE2  SEVCODE
# ...

# %%
df_any['SEVCODE1'] = df_any.SEVCODE1.replace(2,0)
df_any.head()
# Out:
#    SEVERITYCODE  ADDRTYPE  WEATHER  ROADCOND  LIGHTCOND  SPEEDING  \
# 0             2         1        3         2          1         0
# 1             1         2        2         2          2         0
# 2             1         2        3         1          1         0
# 3             1         2        1         1          1         0
# 4             2         1        2         2          1         0
#
#    HITPARKEDCAR  COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0             2              2            2         0            0         2
# 1             2              5            2         0            0         2
# 2             2              1            4         0            0         3
# 3             2              4            3         0            0         3
# 4             2              2            2         0            0         2
#
#                   INCDTTM  DAYTIME  SEVCODE1  SEVCODE2  SEVCODE
# ...

# %%
df_any['SEVCODE1'].value_counts()
# Out:
# 1    136485
# 0     58188
# Name: SEVCODE1, dtype: int64

# %%
df_any['SEVCODE2'] = df_any.SEVCODE2.replace(1,0)
df_any['SEVCODE2'] = df_any.SEVCODE2.replace(2,1)
df_any.head()
# Out:
#    SEVERITYCODE  ADDRTYPE  WEATHER  ROADCOND  LIGHTCOND  SPEEDING  \
# 0             2         1        3         2          1         0
# 1             1         2        2         2          2         0
# 2             1         2        3         1          1         0
# 3             1         2        1         1          1         0
# 4             2         1        2         2          1         0
#
#    HITPARKEDCAR  COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0             2              2            2         0            0         2
# 1             2              5            2         0            0         2
# 2             2              1            4         0            0         3
# 3             2              4            3         0            0         3
# 4             2              2            2         0            0         2
#
#                   INCDTTM  DAYTIME  SEVCODE1  SEVCODE2  SEVCODE
# ...

# %%
df_any['SEVCODE2'].value_counts()
# Out:
# 0    136485
# 1     58188
# Name: SEVCODE2, dtype: int64

# %%
df_fin=df_any[['SEVERITYCODE','ADDRTYPE','WEATHER','ROADCOND','LIGHTCOND','COLLISIONTYPE','DAYTIME']]
df_fin.head()
# Out:
#    SEVERITYCODE  ADDRTYPE  WEATHER  ROADCOND  LIGHTCOND  COLLISIONTYPE  \
# 0             2         1        3         2          1              2
# 1             1         2        2         2          2              5
# 2             1         2        3         1          1              1
# 3             1         2        1         1          1              4
# 4             2         1        2         2          1              2
#
#    DAYTIME
# 0        2
# 1        2
# 2        1
# 3        1
# 4        1

# %%
df_fin.shape
# Out:
# (194673, 7)

# %%
df_fin=df_fin[df_fin.ADDRTYPE != 3]
df_fin=df_fin[df_fin.ADDRTYPE != 0]
df_fin.shape
# Out:
# (191996, 7)

# %%
df_fin=df_fin[df_fin.WEATHER != 0]
df_fin=df_fin[df_fin.WEATHER != 4]
df_fin=df_fin[df_fin.WEATHER != 5]
df_fin=df_fin[df_fin.WEATHER != 6]
df_fin=df_fin[df_fin.WEATHER != 7]
df_fin=df_fin[df_fin.WEATHER != 8]
df_fin=df_fin[df_fin.WEATHER != 9]
df_fin=df_fin[df_fin.WEATHER != 10]
df_fin=df_fin[df_fin.WEATHER != 11]
df_fin.shape
# Out:
# (170595, 7)

# %%
df_fin=df_fin[df_fin.ROADCOND != 0]
df_fin=df_fin[df_fin.ROADCOND != 3]
df_fin=df_fin[df_fin.ROADCOND != 4]
df_fin=df_fin[df_fin.ROADCOND != 5]
df_fin=df_fin[df_fin.ROADCOND != 6]
df_fin=df_fin[df_fin.ROADCOND != 7]
df_fin=df_fin[df_fin.ROADCOND != 8]
df_fin=df_fin[df_fin.ROADCOND != 9]
df_fin.shape
# Out:
# (168210, 7)

# %%
df_fin=df_fin[df_fin.LIGHTCOND != 0]
df_fin=df_fin[df_fin.LIGHTCOND != 5]
df_fin=df_fin[df_fin.LIGHTCOND != 9]
df_fin=df_fin[df_fin.LIGHTCOND != 8]
df_fin.shape
# Out:
# (165734, 7)

# %%
df_fin=df_fin[df_fin.COLLISIONTYPE != 0]
df_fin.shape
# Out:
# (165718, 7)

# %%
df_fin=df_fin[df_fin.DAYTIME != 0]
df_fin.shape
# Out:
# (143561, 7)

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %%
Feature = df_fin[['ADDRTYPE','WEATHER','ROADCOND','LIGHTCOND','COLLISIONTYPE','DAYTIME']]
X= Feature
Y=df_fin['SEVERITYCODE'].values
X= preprocessing.StandardScaler().fit(X).transform(X)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:4: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (114848, 6) (114848,)
# Test set: (28713, 6) (28713,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR
yhat = LR.predict(X_test)
yhat
yhat_prob = LR.predict_proba(X_test)
yhat_prob
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
# Out:
# 0.6835231428272908
